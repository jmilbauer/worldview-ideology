# %%
import pickle
from tqdm import tqdm

from gensim.models.word2vec import Word2Vec
import numpy as np
from sklearn.cross_decomposition import CCA
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords, wordnet

# %% [markdown]
# # Worldview & Ideology Analysis

# %% [markdown]
# This notebook contains examples of how to perform the analysis from "Aligning Multidimensional Worldviews and Discovering Ideological Differences" (Milbauer et al., 2021)

# %% [markdown]
# ## Loading the trained embeddings

# %% [markdown]
# First, we load the trained embeddings, and quickly examine them to see if they make sense.
# We are using small text samples (500k tokens), so embeddings may not be very good.

# %%
model_a = Word2Vec.load('models/politics.word2vec.model')
model_b = Word2Vec.load('models/the_donald.word2vec.model')

posWords = ['biden']
negWords = []
for x in model_a.wv.most_similar(positive=posWords, negative=negWords):
    print(x)
print()
for x in model_b.wv.most_similar(positive=posWords, negative=negWords):
    print(x)
# Out:
# ('harris', 0.7471194267272949)
# ('warren', 0.7145416736602783)
# ('sanders', 0.6976892948150635)
# ('bernie', 0.6945799589157104)
# ('joe_biden', 0.6156193017959595)
# ('kamala', 0.6149285435676575)
# ('buttigieg', 0.5869153141975403)
# ('candidate', 0.5764375925064087)
# ('joe', 0.5390542149543762)
# ('nomination', 0.5072815418243408)
#
# ('harris', 0.5104426145553589)
# ('creepy_joe', 0.48085713386535645)
# ('joe_biden', 0.4680749475955963)
# ('joe', 0.4410553574562073)
# ('sniffing', 0.4272039234638214)
# ('warren', 0.42609065771102905)
# ('sleepy_joe', 0.4177272915840149)
# ('kamala', 0.4112250804901123)
# ('nominee', 0.3884388506412506)
# ('hillary', 0.38795745372772217)

# %% [markdown]
# ## Aligning the embeddings

# %% [markdown]
# First, we find the overlapping vocabulary of the two models, and use this to construct an embedding matrix for each model.

# %%
vocab_a = list(set(model_a.wv.vocab.keys()))
vocab_b = list(set(model_b.wv.vocab.keys()))

shared_vocab = set.intersection(set(vocab_a),
                                set(vocab_b))
shared_vocab = list(sorted(list(shared_vocab)))
combo_vocab = set.union(set(vocab_a),
                                set(vocab_b))

w2idx = { w:i for i,w in enumerate(shared_vocab) }
a2idx = { w:i for i,w in enumerate(vocab_a) }
idx2b = { i:w for i,w in enumerate(vocab_b) }

mtxA = np.vstack([model_a.wv[w] for w in shared_vocab])
mtxB = np.vstack([model_b.wv[w] for w in shared_vocab])
mtxA_ = np.vstack([model_a.wv[w] for w in vocab_a])
mtxB_ = np.vstack([model_b.wv[w] for w in vocab_b])

# %% [markdown]
# We then select only the N most common words as anchors to train our alignment

# %%
counts = pickle.load(open('data/counts.pkl', 'rb'))
n = 5000
topN = [y for x,y in sorted([(counts[w], w) for w in w2idx], reverse=True)][:n]
idxs = [w2idx[w] for w in topN]

# %%
anchorA = mtxA[idxs, :]
anchorB = mtxB[idxs, :]

# %% [markdown]
# Next, we use two different techniques for aligning the embeddings: SVD and CCA

# %%
def align_svd(source, target):
    product = np.matmul(source.transpose(), target)
    U, s, V = np.linalg.svd(product)
    T = np.matmul(U,V)
    return T

svd = align_svd(anchorA, anchorB)
svdA = mtxA_.dot(svd)
svdB = mtxB_

# %%
# def align_cca(source, target):
#     N_dims = source.shape[1]
#     cca = CCA(n_components=N_dims, max_iter=2000)
#     cca.fit(source, target)
#     return cca

# cca = align_cca(anchorA, anchorB)
# ccaA, ccaB = cca.transform(mtxA, mtxB)

# %%
def build_translator(a, b, a2idx, idx2b):
    sims = cosine_similarity(a, b)
    most_sims = np.argsort(sims, axis=1)[:, ::-1]
    
    def translator(w, k=1):
        idx = a2idx[w]
        idxs = most_sims[idx, :k]
        words = [idx2b[i] for i in idxs]
        return words, sims[idx, idxs]
    
    return translator

# %%
translator = build_translator(svdA, svdB, a2idx, idx2b)

# %% [markdown]
# ## Exploring the Alignment

# %% [markdown]
# We now explore three different ways of using the alignmed embeddings to explore the worldview and ideology of the two communities.

# %% [markdown]
# ### Misalignment

# %%
translator('fox', k=5)
# Out:
# (['fox', 'news', 'msm', 'media', 'cnn'],
#  array([0.6001878 , 0.51686245, 0.50817823, 0.48632458, 0.48302713],
#        dtype=float32))

# %%
misaligned = []
scores = []

for w in shared_vocab:
    w_ = translator(w)[0][0]
    s = translator(w)[1][0]
    if w != w_:
        misaligned.append((w, w_))
        scores.append(s)
        
print(len(misaligned) / len(shared_vocab))
# Out:
# 0.3664901664145234

# %% [markdown]
# ### Antonyms

# %%
def get_antonyms(vocab):
    antonyms = []
    for w in tqdm(vocab):
        for synset in wordnet.synsets(w):
            for lemma in synset.lemmas():
                if lemma.antonyms():
                    antonyms.append((w, lemma.antonyms()[0].name()))
    antonyms = set(antonyms)
    return antonyms

antonyms = get_antonyms(combo_vocab)
# Out:
# 100%|██████████| 11909/11909 [00:07<00:00, 1675.90it/s]

# %%
for mPair in misaligned:
    if mPair in antonyms or (mPair[0], mPair[1]) in antonyms:
        print(mPair)
# Out:
# ('civilian', 'military')
# ('decrease', 'increase')
# ('disagree', 'agree')
# ('disrespect', 'respect')
# ('illogical', 'logical')
# ('inaccurate', 'accurate')
# ('indirectly', 'directly')
# ('ineffective', 'effective')
# ('intolerant', 'tolerant')
# ('invalid', 'valid')
# ('liability', 'asset')
# ('sell', 'buy')
# ('sells', 'buy')
# ('unreasonable', 'reasonable')
# ('unwilling', 'willing')
# ('weakness', 'strength')
# ('west', 'east')

# %% [markdown]
# ### Translation / Conceptual Homomorphisms

# %%
unique_vocab = []
for w in model_a.wv.vocab:
    if w not in model_b.wv.vocab:
        unique_vocab.append(w)

# %%
for w in unique_vocab:
    print(f"{w} -> {translator(w)}")
# Out:
# coopted -> (['chat'], array([0.29226458], dtype=float32))
# allied -> (['aligned'], array([0.29129168], dtype=float32))
# polarizing -> (['independents'], array([0.27693155], dtype=float32))
# commits -> (['commit'], array([0.33745366], dtype=float32))
# atrocities -> (['terrorists'], array([0.33574992], dtype=float32))
# yemen -> (['syria'], array([0.4033485], dtype=float32))
# hostage -> (['tortured'], array([0.28057888], dtype=float32))
# safety_net -> (['medicare'], array([0.41101658], dtype=float32))
# safety_nets -> (['handouts'], array([0.3434365], dtype=float32))
# utilities -> (['hospitals'], array([0.34818196], dtype=float32))
# apt -> (['inaccurate'], array([0.27883196], dtype=float32))
# xenophobia -> (['europe'], array([0.32490867], dtype=float32))
# monstrous -> (['el_chapo'], array([0.25076938], dtype=float32))
# moreso -> (['align'], array([0.25163296], dtype=float32))
# stimulate -> (['economy'], array([0.3339837], dtype=float32))
# anecdotes -> (['boomers'], array([0.28000492], dtype=float32))
# percentages -> (['antiwhite'], array([0.3065506], dtype=float32))
# gaffe -> (['tweet'], array([0.28022057], dtype=float32))
# hickenlooper -> (['warren'], array([0.34321848], dtype=float32))
# contributors -> (['donors'], array([0.30607384], dtype=float32))
# civil_discussion -> (['subreddit'], array([0.42238685], dtype=float32))
# courteous -> (['moderators'], array([0.42996362], dtype=float32))
# attack_ideas -> (['moderators'], array([0.47308162], dtype=float32))
# personal_insults -> (['standalone_posts'], array([0.4764346], dtype=float32))
# troll_accusations -> (['performed_automatically'], array([0.51061064], dtype=float32))
# wishing_death/physical -> (['performed_automatically'], array([0.594555], dtype=float32))
# rule_violations -> (['performed_automatically'], array([0.63353837], dtype=float32))
# permanent_ban -> (['performed_automatically'], array([0.69331694], dtype=float32))
# inflated -> (['budget'], array([0.27920988], dtype=float32))
# requesting -> (['precedent'], array([0.27033937], dtype=float32))
# feasible -> (['solution'], array([0.36464146], dtype=float32))
# ec -> (['electoral_college'], array([0.47711372], dtype=float32))
# dehumanization -> (['brainwashing'], array([0.29910597], dtype=float32))
# negotiation -> (['negotiating'], array([0.289541], dtype=float32))
# execute -> (['provoke'], array([0.27264738], dtype=float32))
# administrative -> (['justice_department'], array([0.29290125], dtype=float32))
# whataboutism -> (['argument'], array([0.30756128], dtype=float32))
# commit_atrocities -> (['negotiate'], array([0.2700272], dtype=float32))
# drone_strikes -> (['obama'], array([0.34441143], dtype=float32))
# carlson -> (['tucker'], array([0.3239869], dtype=float32))
# regimes -> (['authoritarian'], array([0.33497286], dtype=float32))
# stages -> (['ie'], array([0.26539838], dtype=float32))
# efficiently -> (['resources'], array([0.28185543], dtype=float32))
# technological -> (['technology'], array([0.33301204], dtype=float32))
# killings -> (['murders'], array([0.35669294], dtype=float32))
# casino -> (['finances'], array([0.28006515], dtype=float32))
# coma -> (['drinking'], array([0.29474348], dtype=float32))
# nuanced -> (['important'], array([0.27798948], dtype=float32))
# criminally -> (['infect'], array([0.2995801], dtype=float32))
# decreasing -> (['increasing'], array([0.34478015], dtype=float32))
# concessions -> (['sanctions'], array([0.2848628], dtype=float32))
# obtuse -> (['ignorant'], array([0.3283191], dtype=float32))
# consistency -> (['universal'], array([0.272788], dtype=float32))
# binary -> (['reality'], array([0.25724646], dtype=float32))
# disconnect -> (['conflicts'], array([0.28508243], dtype=float32))
# motivate -> (['vote'], array([0.28648278], dtype=float32))
# prestigious -> (['school'], array([0.38889453], dtype=float32))
# confederacy -> (['slavery'], array([0.28749362], dtype=float32))
# detention_facilities -> (['border'], array([0.38781098], dtype=float32))
# family_separation -> (['cages'], array([0.3386393], dtype=float32))
# north_koreans -> (['korea'], array([0.30587274], dtype=float32))
# isle -> (['aisle'], array([0.38187188], dtype=float32))
# assign -> (['apply'], array([0.2661715], dtype=float32))
# purity_test -> (['identity_politics'], array([0.28708452], dtype=float32))
# hypothetically -> (['realistically'], array([0.27001712], dtype=float32))
# legitimacy -> (['credibility'], array([0.29557282], dtype=float32))
# stems -> (['hood'], array([0.26896033], dtype=float32))
# entertain -> (['26_times'], array([0.2746458], dtype=float32))
# proposals -> (['policies'], array([0.33414903], dtype=float32))
# preferable -> (['hashtag'], array([0.26724052], dtype=float32))
# militias -> (['brownshirts'], array([0.32578316], dtype=float32))
# lap -> (['dildo'], array([0.27065632], dtype=float32))
# exceptionally -> (['incredibly'], array([0.3713503], dtype=float32))
# interest_rates -> (['loan'], array([0.40837368], dtype=float32))
# unethical -> (['immoral'], array([0.290178], dtype=float32))
# discourage -> (['prevent'], array([0.31039295], dtype=float32))
# restrictive -> (['hippies'], array([0.27221283], dtype=float32))
# hoops -> (['background_check'], array([0.2898285], dtype=float32))
# daily_wire -> (['drudge'], array([0.32153514], dtype=float32))
# propagandists -> (['hypocrites'], array([0.28724077], dtype=float32))
# holocaust_survivors -> (['concentration_camps'], array([0.33515868], dtype=float32))
# insisting -> (['marching'], array([0.26765895], dtype=float32))
# casualties -> (['war'], array([0.31970865], dtype=float32))
# qualifying -> (['qualified'], array([0.3139558], dtype=float32))
# marketplace -> (['market'], array([0.31245035], dtype=float32))
# roosevelt -> (['ii'], array([0.30625018], dtype=float32))
# atrocious -> (['terrible'], array([0.31630856], dtype=float32))
# reliably -> (['harvesting'], array([0.2560084], dtype=float32))
# snarky -> (['post'], array([0.31199995], dtype=float32))
# attitudes -> (['twisted'], array([0.25581872], dtype=float32))
# r/politics -> (['reddit'], array([0.429268], dtype=float32))
# inflict -> (['misery'], array([0.3087564], dtype=float32))
# misdemeanor -> (['felony'], array([0.37147924], dtype=float32))
# graduated_cum -> (['degree'], array([0.3413293], dtype=float32))
# laude -> (['economics'], array([0.35857552], dtype=float32))
# unqualified -> (['bartender'], array([0.3163943], dtype=float32))
# enterprise -> (['properties'], array([0.2751403], dtype=float32))
# jeff_bezos -> (['real_estate'], array([0.28769892], dtype=float32))
# shareholders -> (['profits'], array([0.39976692], dtype=float32))
# debts -> (['debt'], array([0.37276778], dtype=float32))
# considerable -> (['abuses'], array([0.26377952], dtype=float32))
# townhall -> (['news'], array([0.3207605], dtype=float32))
# scapegoat -> (['blame'], array([0.2651688], dtype=float32))
# perpetuating -> (['agenda'], array([0.27758545], dtype=float32))
# perpetuate -> (['daily_basis'], array([0.26435986], dtype=float32))
# contradicts -> (['inaccurate'], array([0.2985206], dtype=float32))
# confirmation_bias -> (['downvotes'], array([0.2879085], dtype=float32))
# solidly -> (['overwhelmingly'], array([0.27236992], dtype=float32))
# rourke -> (['booker'], array([0.2898207], dtype=float32))
# sophisticated -> (['sedition'], array([0.27799648], dtype=float32))
# politely -> (['listening'], array([0.27372748], dtype=float32))
# vladimir_putin -> (['hilary'], array([0.29600134], dtype=float32))
# murdoch -> (['media'], array([0.29351544], dtype=float32))
# wharton -> (['degree'], array([0.3566861], dtype=float32))
# nepotism -> (['ivanka'], array([0.37524083], dtype=float32))
# charter -> (['school'], array([0.28643268], dtype=float32))
# reasoned -> (['reasoning'], array([0.28615028], dtype=float32))
# poisoned -> (['broken'], array([0.2841581], dtype=float32))
# knowledgeable -> (['smarter'], array([0.26544487], dtype=float32))
# hi_` -> (['antitrump_domain'], array([0.42061508], dtype=float32))
# /r/politics -> (['submission'], array([0.39233243], dtype=float32))
# following_reason -> (['submission'], array([0.48058963], dtype=float32))
# normalizing -> (['complicit'], array([0.28834623], dtype=float32))
# editorial -> (['news'], array([0.29263225], dtype=float32))
# assault_rifle -> (['firearm'], array([0.3897058], dtype=float32))
# phrasing -> (['publication'], array([0.30627918], dtype=float32))
# tensions -> (['korea'], array([0.3419904], dtype=float32))
# costly -> (['fees'], array([0.27588183], dtype=float32))
# namely -> (['similar'], array([0.24676852], dtype=float32))
# compel -> (['enforce'], array([0.2691316], dtype=float32))
# mfa -> (['gender_studies'], array([0.29222652], dtype=float32))
# assassinated -> (['murdered'], array([0.27728835], dtype=float32))
# wellbeing -> (['decisions'], array([0.30581817], dtype=float32))
# systematically -> (['killed'], array([0.27728114], dtype=float32))
# siding -> (['obsessed'], array([0.26600176], dtype=float32))
# deceptive -> (['reality'], array([0.2939238], dtype=float32))
# gorsuch -> (['justices'], array([0.38897854], dtype=float32))
# ram -> (['unconstitutional'], array([0.27122414], dtype=float32))
# benghazi -> (['hillary'], array([0.32589442], dtype=float32))
# educating -> (['informed'], array([0.33738038], dtype=float32))
# uniforms -> (['dress'], array([0.2965192], dtype=float32))
# quicker -> (['faster'], array([0.3929823], dtype=float32))
# faking -> (['mad'], array([0.27278408], dtype=float32))
# deficit -> (['trillion'], array([0.35451803], dtype=float32))
# deployment -> (['construction'], array([0.3075638], dtype=float32))
# framing -> (['twist'], array([0.30534884], dtype=float32))
# oranges -> (['distinction'], array([0.24741071], dtype=float32))
# segregationist -> (['jim_crow'], array([0.27466443], dtype=float32))
# bracket -> (['mortgage'], array([0.3333303], dtype=float32))
# geopolitical -> (['nato'], array([0.3305174], dtype=float32))
# drastic -> (['mood'], array([0.26665828], dtype=float32))
# purity -> (['identity_politics'], array([0.28195867], dtype=float32))
# torch -> (['ooh'], array([0.28473365], dtype=float32))
# obstructing -> (['obstruction'], array([0.26012105], dtype=float32))
# circlejerk -> (['haters'], array([0.31975257], dtype=float32))
# factually -> (['blatantly'], array([0.27081838], dtype=float32))
# incels -> (['leftists'], array([0.3259622], dtype=float32))
# aides -> (['pallets'], array([0.28325287], dtype=float32))
# moscow -> (['russia'], array([0.28521535], dtype=float32))
# segregated -> (['segregation'], array([0.36433527], dtype=float32))
# gerrymandering -> (['electoral_college'], array([0.41846249], dtype=float32))
# poorer -> (['middle_class'], array([0.35492253], dtype=float32))
# administrators -> (['requiring'], array([0.28119206], dtype=float32))
# vice_versa -> (['black'], array([0.28906628], dtype=float32))
# convey -> (['clarify'], array([0.32520226], dtype=float32))
# gag -> (['miss'], array([0.27097026], dtype=float32))
# williamson -> (['gabbard'], array([0.34268454], dtype=float32))
# margins -> (['polls'], array([0.3040586], dtype=float32))
# short_sighted -> (['greedy'], array([0.31750688], dtype=float32))
# troubling -> (['amazed'], array([0.27341172], dtype=float32))
# neoliberal -> (['left'], array([0.29642347], dtype=float32))
# govern -> (['republic'], array([0.27660725], dtype=float32))
# stump -> (['teleprompter'], array([0.2963385], dtype=float32))
# dishonesty -> (['lies'], array([0.32644787], dtype=float32))
# twisting -> (['stir'], array([0.2730105], dtype=float32))
# policy_proposals -> (['stances'], array([0.3350254], dtype=float32))
# deregulation -> (['regulations'], array([0.33043352], dtype=float32))
# 1993 -> (['2001'], array([0.36952764], dtype=float32))
# banana -> (['beers'], array([0.26767966], dtype=float32))
# occupying -> (['invasion'], array([0.31637067], dtype=float32))
# sidebar -> (['shadow_banned'], array([0.3156977], dtype=float32))
# submissions -> (['four_bricks'], array([0.33204803], dtype=float32))
# donnie -> (['he'], array([0.3388163], dtype=float32))
# defund -> (['eliminate'], array([0.3342278], dtype=float32))
# refund -> (['tax'], array([0.31706125], dtype=float32))
# single_payer -> (['healthcare'], array([0.42897084], dtype=float32))
# whatabout -> (['james_comey'], array([0.32297888], dtype=float32))
# photo_ops -> (['diplomacy'], array([0.31909946], dtype=float32))
# kju -> (['iran'], array([0.38159394], dtype=float32))
# pardoned -> (['charged'], array([0.34192678], dtype=float32))
# refuge -> (['territory'], array([0.26772714], dtype=float32))
# realities -> (['scenarios'], array([0.29318804], dtype=float32))
# devastating -> (['indictment'], array([0.26999414], dtype=float32))
# slipping -> (['sway'], array([0.25381124], dtype=float32))
# bolton -> (['iran'], array([0.36487257], dtype=float32))
# stressful -> (['messed'], array([0.2954744], dtype=float32))
# net_worth -> (['income'], array([0.40264764], dtype=float32))
# nominated -> (['nomination'], array([0.3920881], dtype=float32))
# qualification -> (['qualified'], array([0.32618335], dtype=float32))
# watergate -> (['nixon'], array([0.29343253], dtype=float32))
# dprk -> (['north_korea'], array([0.35696876], dtype=float32))
# bartending -> (['bartender'], array([0.31983778], dtype=float32))
# consist -> (['^way'], array([0.35259387], dtype=float32))
# kushner -> (['ivanka'], array([0.34328395], dtype=float32))
# overlook -> (['conflate'], array([0.31765643], dtype=float32))
# politically_motivated -> (['attempted_murder'], array([0.28440988], dtype=float32))
# prohibit -> (['regulate'], array([0.30588576], dtype=float32))
# kochs -> (['soros'], array([0.2717405], dtype=float32))
# governance -> (['society'], array([0.30288026], dtype=float32))
# arbitrarily -> (['instances'], array([0.23727633], dtype=float32))
# indict -> (['barr'], array([0.3291094], dtype=float32))
# trivial -> (['ss'], array([0.26804054], dtype=float32))
# 84 -> (['%'], array([0.2883957], dtype=float32))
# last_calendar -> (['performed_automatically'], array([0.3913456], dtype=float32))
# january_29 -> (['performed_automatically'], array([0.43794298], dtype=float32))
# december_29 -> (['please_contact'], array([0.4263974], dtype=float32))
# exceed -> (['increase'], array([0.29228455], dtype=float32))
# atrocity -> (['concentration_camps'], array([0.30942664], dtype=float32))
# misplaced -> (['whiteness'], array([0.26144972], dtype=float32))
# discouraging -> (['patterns'], array([0.26343578], dtype=float32))
# tiffany -> (['she'], array([0.3467151], dtype=float32))
# lip_service -> (['fairness'], array([0.28372332], dtype=float32))
# securing -> (['secure'], array([0.27731588], dtype=float32))
# enacting -> (['fascism'], array([0.27108374], dtype=float32))
# attribute -> (['calculated'], array([0.26230907], dtype=float32))
# trends -> (['graph'], array([0.30266368], dtype=float32))
# 41 -> (['%'], array([0.34510612], dtype=float32))
# characterized -> (['academics'], array([0.287813], dtype=float32))
# deficits -> (['increase'], array([0.31237411], dtype=float32))
# disastrous -> (['failure'], array([0.30521858], dtype=float32))
# inequality -> (['poverty'], array([0.33453593], dtype=float32))
# overtly -> (['pos'], array([0.26661834], dtype=float32))
# dangers -> (['problems'], array([0.24741293], dtype=float32))
# r/politics_requires -> (['meme_reference'], array([0.39638335], dtype=float32))
# fully_participate -> (['please_contact'], array([0.5898004], dtype=float32))
# urgent -> (['emergency'], array([0.30862677], dtype=float32))
# risked -> (['lives'], array([0.318166], dtype=float32))
# desegregation -> (['busing'], array([0.35125026], dtype=float32))
# unfit -> (['qualified'], array([0.2927896], dtype=float32))
# splitting -> (['split'], array([0.3250976], dtype=float32))
# constituency -> (['electorate'], array([0.29489893], dtype=float32))
# gerrymander -> (['electoral_college'], array([0.35859683], dtype=float32))
# committing_crimes -> (['gangs'], array([0.2798277], dtype=float32))
# statistical -> (['households'], array([0.3221449], dtype=float32))
# outliers -> (['earnings'], array([0.25364065], dtype=float32))
# alarming -> (['encouraging'], array([0.28503945], dtype=float32))
# hostile_foreign -> (['interference'], array([0.3286363], dtype=float32))
# trickle_down -> (['recession'], array([0.32777417], dtype=float32))
# town_hall -> (['presser'], array([0.32024103], dtype=float32))
# student_debt -> (['student_loans'], array([0.4392167], dtype=float32))
# graduating -> (['college'], array([0.41214275], dtype=float32))
# coupled -> (['improved'], array([0.2622137], dtype=float32))
# budgets -> (['spending'], array([0.35571966], dtype=float32))
# extraordinary -> (['mosques'], array([0.26467666], dtype=float32))
# nuances -> (['nuance'], array([0.28268343], dtype=float32))
# juvenile -> (['child'], array([0.28349775], dtype=float32))
# preventative -> (['medical'], array([0.3770294], dtype=float32))
# earners -> (['rates'], array([0.37061298], dtype=float32))
# police_brutality -> (['police'], array([0.31006137], dtype=float32))
# informing -> (['letting'], array([0.26582935], dtype=float32))
# impactful -> (['informative'], array([0.29760367], dtype=float32))
# forbes -> (['wexner'], array([0.3414736], dtype=float32))
# inherited -> (['jimmy_carter'], array([0.27253836], dtype=float32))
# forgiving -> (['debt'], array([0.35166314], dtype=float32))
# maddow -> (['npr'], array([0.27578026], dtype=float32))
# torturing -> (['rapists'], array([0.32995787], dtype=float32))
# responsibly -> (['lives'], array([0.24622117], dtype=float32))
# concede -> (['admit'], array([0.2716724], dtype=float32))
# lacks -> (['zero'], array([0.3061966], dtype=float32))
# simpler -> (['lists'], array([0.26839843], dtype=float32))
# specifics -> (['researching'], array([0.28605857], dtype=float32))
# huawei -> (['eu'], array([0.3007206], dtype=float32))
# $_775 -> (['per'], array([0.3490499], dtype=float32))
# methodology -> (['autists'], array([0.27827373], dtype=float32))
# pete_buttigieg -> (['sanders'], array([0.26872215], dtype=float32))
# m4a -> (['medicare'], array([0.40729016], dtype=float32))
# private_insurance -> (['medicare'], array([0.3975066], dtype=float32))
# criticisms -> (['criticism'], array([0.365772], dtype=float32))
# jfc -> (['...'], array([0.2948312], dtype=float32))
# apologist -> (['domestic_terrorism'], array([0.2737451], dtype=float32))
# interpreting -> (['regulating'], array([0.27688742], dtype=float32))
# subsidized -> (['pays'], array([0.32514092], dtype=float32))
# indefensible -> (['blah'], array([0.27606204], dtype=float32))
# suited -> (['fit'], array([0.2488701], dtype=float32))
# blogger -> (['journalist'], array([0.40037572], dtype=float32))
# vat -> (['ubi'], array([0.32564184], dtype=float32))
# consuming -> (['demonic'], array([0.2739806], dtype=float32))
# attributed -> (['smith'], array([0.3065349], dtype=float32))
# billed -> (['fee'], array([0.30194485], dtype=float32))
# estate -> (['tax'], array([0.3492251], dtype=float32))
# neglect -> (['child'], array([0.28085515], dtype=float32))
# /r/politics_within -> (['performed_automatically'], array([0.52550036], dtype=float32))
# three_days -> (['performed_automatically'], array([0.415525], dtype=float32))
# debatable -> (['plausible'], array([0.28794438], dtype=float32))
# buses -> (['spaces'], array([0.28130883], dtype=float32))
# ballot_box -> (['election'], array([0.31907278], dtype=float32))
# photographs -> (['pictures'], array([0.42157876], dtype=float32))
# manslaughter -> (['attempted_murder'], array([0.35593197], dtype=float32))
# strawman -> (['ad_hominem'], array([0.3182442], dtype=float32))
# dementia -> (['instinct'], array([0.28212166], dtype=float32))
# 30s -> (['94'], array([0.28773192], dtype=float32))
# execution -> (['death'], array([0.28743953], dtype=float32))
# imprison -> (['detain'], array([0.302603], dtype=float32))
# detrimental -> (['sovereignty'], array([0.284319], dtype=float32))
# imprisoning -> (['unborn'], array([0.32040498], dtype=float32))
# bailouts -> (['tax_cuts'], array([0.39087334], dtype=float32))
# autocratic -> (['authoritarian'], array([0.34379798], dtype=float32))
# federally -> (['state'], array([0.2969778], dtype=float32))
# ineligible -> (['eligible'], array([0.28770083], dtype=float32))
# segregationists -> (['kamala_harris'], array([0.32336307], dtype=float32))
# electors -> (['electoral_votes'], array([0.44098908], dtype=float32))
# invalidate -> (['refute'], array([0.2739771], dtype=float32))
# paywall -> (['nyt'], array([0.35208222], dtype=float32))
# vaguely -> (['depth'], array([0.24017766], dtype=float32))
# antiwar -> (['joe_rogan'], array([0.31775936], dtype=float32))
# upsetting -> (['ham'], array([0.28054643], dtype=float32))
# demonizing -> (['stopping'], array([0.32340166], dtype=float32))
# span -> (['significantly'], array([0.27080095], dtype=float32))
# housed -> (['luxury'], array([0.29593956], dtype=float32))
# volunteering -> (['isolated'], array([0.27690485], dtype=float32))
# adderall -> (['diet'], array([0.2855141], dtype=float32))
# justifying -> (['labeling'], array([0.26208788], dtype=float32))
# populist -> (['totalitarian'], array([0.32494888], dtype=float32))
# capitalists -> (['communists'], array([0.3405865], dtype=float32))
# predatory -> (['loans'], array([0.27091032], dtype=float32))
# payed -> (['paid'], array([0.38258776], dtype=float32))
# dysfunctional -> (['inept'], array([0.31877083], dtype=float32))
# massacre -> (['happened'], array([0.2987], dtype=float32))
# 700 -> (['$'], array([0.31946117], dtype=float32))
# hoarding -> (['wealth'], array([0.38919795], dtype=float32))
# misunderstand -> (['grasp'], array([0.29391003], dtype=float32))
# hoard -> (['wealth'], array([0.35321134], dtype=float32))
# faction -> (['farage'], array([0.2426761], dtype=float32))
# factions -> (['coalition'], array([0.30412948], dtype=float32))
# detaining -> (['deporting'], array([0.40524793], dtype=float32))
# withdrew -> (['14'], array([0.2814671], dtype=float32))
# cheney -> (['bin_laden'], array([0.29418197], dtype=float32))
# moving_forward -> (['deep_fakes'], array([0.24569659], dtype=float32))
# capabilities -> (['advanced'], array([0.29432338], dtype=float32))
# amoral -> (['disingenuous'], array([0.29063195], dtype=float32))
# dehumanize -> (['murderers'], array([0.274876], dtype=float32))
# structural -> (['damage'], array([0.27924204], dtype=float32))
# singular -> (['dominant'], array([0.2605806], dtype=float32))
# measurement -> (['logically'], array([0.28323314], dtype=float32))
# occurring -> (['happening'], array([0.29726675], dtype=float32))
# evolved -> (['communism'], array([0.26633644], dtype=float32))
# economies -> (['economy'], array([0.35143754], dtype=float32))
# rotting -> (['crack'], array([0.2796644], dtype=float32))
# detainment -> (['border'], array([0.34035406], dtype=float32))
# offtopic -> (['subreddit'], array([0.39988363], dtype=float32))
# itt -> (['sub'], array([0.2797121], dtype=float32))
# tariff -> (['tariffs'], array([0.38520095], dtype=float32))
# g20 -> (['ivanka'], array([0.32203937], dtype=float32))
# charities -> (['charity'], array([0.34412703], dtype=float32))
# tantrum -> (['frankly'], array([0.28554702], dtype=float32))
# misrepresenting -> (['defends'], array([0.2756703], dtype=float32))
# compares -> (['comparing'], array([0.27838174], dtype=float32))
# gnd -> (['predictions'], array([0.32276228], dtype=float32))
# aggressively -> (['sow'], array([0.30743933], dtype=float32))
# defying -> (['63'], array([0.28977633], dtype=float32))
# vacuum -> (['influential'], array([0.2605313], dtype=float32))
# pundits -> (['personalities'], array([0.33102417], dtype=float32))
# cynical -> (['but'], array([0.30579528], dtype=float32))
# welfare_programs -> (['welfare'], array([0.4212432], dtype=float32))
# populism -> (['socialism'], array([0.2961381], dtype=float32))
# tulsi_gabbard -> (['primary'], array([0.2809539], dtype=float32))
# impacted -> (['affected'], array([0.2921832], dtype=float32))
# chambers -> (['senate'], array([0.2737603], dtype=float32))
# lump -> (['normalize'], array([0.27375174], dtype=float32))
# restricting -> (['consent'], array([0.30164906], dtype=float32))
# kellyanne -> (['she'], array([0.33480918], dtype=float32))
# satirical -> (['^incite_^violence'], array([0.31211308], dtype=float32))
# interior -> (['meals'], array([0.29130468], dtype=float32))
# enables -> (['donates'], array([0.2806648], dtype=float32))
# workforce -> (['workers'], array([0.3376507], dtype=float32))
# completing -> (['performed_automatically'], array([0.36345926], dtype=float32))
# 1960 -> (['since'], array([0.29753682], dtype=float32))
# historians -> (['christianity'], array([0.2875471], dtype=float32))
# politico -> (['buzzfeed'], array([0.35925424], dtype=float32))
# initiatives -> (['legislation'], array([0.28701445], dtype=float32))
# allocated -> (['electoral_votes'], array([0.36460063], dtype=float32))
# benefiting -> (['benefited'], array([0.30758572], dtype=float32))
# lem -> (['...'], array([0.32168385], dtype=float32))
# indicated -> (['said'], array([0.3133749], dtype=float32))
# bribery -> (['corruption'], array([0.31279856], dtype=float32))
# techniques -> (['manual'], array([0.2848961], dtype=float32))
# speakers -> (['sponsors'], array([0.24472302], dtype=float32))
# discriminatory -> (['discrimination'], array([0.34921417], dtype=float32))
# inquiry -> (['investigation'], array([0.37930933], dtype=float32))
# platitudes -> (['speeches'], array([0.2767721], dtype=float32))
# demonstrates -> (['portray'], array([0.2684736], dtype=float32))
# releases -> (['released'], array([0.33501068], dtype=float32))
# eventual -> (['takeover'], array([0.27029014], dtype=float32))
# bare_minimum -> (['strive'], array([0.25482532], dtype=float32))
# preserving -> (['freedoms'], array([0.31085235], dtype=float32))
# undermines -> (['misleading'], array([0.2764723], dtype=float32))
# contention -> (['2nd'], array([0.27025896], dtype=float32))
# rockets -> (['aircraft'], array([0.29366314], dtype=float32))
# executing -> (['trading'], array([0.27966222], dtype=float32))
# afforded -> (['legally'], array([0.28280774], dtype=float32))
# diplomat -> (['ambassador'], array([0.35533357], dtype=float32))
# rs -> (['rinos'], array([0.3078583], dtype=float32))
# charade -> (['four_bricks'], array([0.26761988], dtype=float32))
# rachel_maddow -> (['podcast'], array([0.3347572], dtype=float32))
# charisma -> (['vp'], array([0.3039273], dtype=float32))
# plight -> (['gratitude'], array([0.27606443], dtype=float32))
# rust_belt -> (['midwest'], array([0.33492815], dtype=float32))
# ultra_wealthy -> (['wealth'], array([0.3406331], dtype=float32))
# deter -> (['avoid'], array([0.29004744], dtype=float32))
# switzerland -> (['uk'], array([0.3771455], dtype=float32))
# pharma -> (['subsidies'], array([0.3073371], dtype=float32))
# delaware -> (['new_york'], array([0.36445218], dtype=float32))
# comparisons -> (['holocaust'], array([0.34279424], dtype=float32))
# frontrunner -> (['nominee'], array([0.3876998], dtype=float32))
# messy -> (['unemployed'], array([0.26694414], dtype=float32))
# geopolitics -> (['china'], array([0.30001467], dtype=float32))
# consolidate -> (['establish'], array([0.29299518], dtype=float32))
# whims -> (['dependent'], array([0.28310457], dtype=float32))
# graduates -> (['graduate'], array([0.33957005], dtype=float32))
# laziness -> (['poverty'], array([0.2688984], dtype=float32))
# payouts -> (['income'], array([0.3329131], dtype=float32))
# endorsements -> (['awards'], array([0.3099731], dtype=float32))
# name_recognition -> (['candidate'], array([0.32418022], dtype=float32))
# international_relations -> (['economics'], array([0.40084165], dtype=float32))
# exaggerating -> (['shark'], array([0.28290987], dtype=float32))
# misogyny -> (['catholic_church'], array([0.2895488], dtype=float32))
# kim_jongun -> (['north_korea'], array([0.420347], dtype=float32))
# placing -> (['thrown'], array([0.27153477], dtype=float32))
# medals -> (['stripes'], array([0.29773238], dtype=float32))
# advisor -> (['helicopter'], array([0.294773], dtype=float32))
# bothering -> (['linking'], array([0.28791142], dtype=float32))
# bailed -> (['sold'], array([0.30442044], dtype=float32))
# private_insurers -> (['insurance'], array([0.325742], dtype=float32))
# basics -> (['understand'], array([0.24986237], dtype=float32))
# singlepayer -> (['healthcare'], array([0.3991033], dtype=float32))
# prevention -> (['murders'], array([0.26151162], dtype=float32))
# strategist -> (['traitor'], array([0.2817815], dtype=float32))
# john_bolton -> (['uniparty'], array([0.28330407], dtype=float32))
# =/= -> (['not'], array([0.26004896], dtype=float32))
# unrealistic -> (['flawed'], array([0.2877767], dtype=float32))
# incarceration -> (['rapists'], array([0.29403526], dtype=float32))
# noun -> (['polish'], array([0.28213876], dtype=float32))
# persecuted_minorities -> (['categories'], array([0.31736124], dtype=float32))
# deliberately_imprisoned -> (['detention_centers'], array([0.31295905], dtype=float32))
# relatively_small -> (['regions'], array([0.26852003], dtype=float32))
# inadequate_facilities -> (['detention_centers'], array([0.36766934], dtype=float32))
# dachau -> (['nazis'], array([0.37677845], dtype=float32))
# physician -> (['medical'], array([0.2942441], dtype=float32))
# rio_grande -> (['river'], array([0.35663784], dtype=float32))
# infants -> (['children'], array([0.41034544], dtype=float32))
# examined -> (['obtained'], array([0.30276808], dtype=float32))
# 39 -> (['40'], array([0.416872], dtype=float32))
# temperatures -> (['co2'], array([0.36973378], dtype=float32))
# adequate -> (['housing'], array([0.33947742], dtype=float32))
# el_paso -> (['new_hampshire'], array([0.2984175], dtype=float32))
# blankets -> (['water'], array([0.38723627], dtype=float32))
# senile -> (['zombie'], array([0.30368415], dtype=float32))
# recognizes -> (['affects'], array([0.25698823], dtype=float32))
# implication -> (['conclusion'], array([0.27556968], dtype=float32))
# essay -> (['article'], array([0.32474983], dtype=float32))
# distinct -> (['classical'], array([0.2727077], dtype=float32))
# jon_stewart -> (['tucker'], array([0.32986957], dtype=float32))
# biases -> (['own'], array([0.30228642], dtype=float32))
# commenter -> (['comment'], array([0.31073132], dtype=float32))
# shittier -> (['formerly'], array([0.27608046], dtype=float32))
# hindsight -> (['ancestors'], array([0.27773997], dtype=float32))
# grift -> (['fame'], array([0.2781749], dtype=float32))
# bernie_bros -> (['conspiracy_theorists'], array([0.30447346], dtype=float32))
# grades -> (['attend'], array([0.30125815], dtype=float32))
# tasked -> (['professionals'], array([0.27165118], dtype=float32))
# rights_abuses -> (['genocide'], array([0.26923257], dtype=float32))
# maximize -> (['save'], array([0.2963301], dtype=float32))
# vanity -> (['waste'], array([0.34435835], dtype=float32))
# evaluate -> (['critically'], array([0.2524706], dtype=float32))
# fueled -> (['led'], array([0.3077725], dtype=float32))
# undocumented_immigrants -> (['illegal_aliens'], array([0.4247082], dtype=float32))
# thirty -> (['20'], array([0.3256164], dtype=float32))
# googling -> (['iphone'], array([0.32323813], dtype=float32))
# withdraw -> (['attorneys'], array([0.31281093], dtype=float32))
# six_months -> (['weeks'], array([0.3510725], dtype=float32))
# revenues -> (['revenue'], array([0.3831248], dtype=float32))
# semester -> (['graduate'], array([0.3543102], dtype=float32))
# inspection -> (['department'], array([0.28993425], dtype=float32))
# fear_mongering -> (['bullshit'], array([0.29215622], dtype=float32))
# notoriously -> (['especially'], array([0.26564127], dtype=float32))
# dictatorships -> (['nazi_germany'], array([0.33745], dtype=float32))
# enlighten -> (['ashamed'], array([0.26661682], dtype=float32))
# contradicting -> (['stance'], array([0.29069734], dtype=float32))
# inspire -> (['roll'], array([0.2665368], dtype=float32))
# surge -> (['shitstorm'], array([0.28466848], dtype=float32))
# argues -> (['says'], array([0.2968108], dtype=float32))
# licensing -> (['gun'], array([0.28262967], dtype=float32))
# validate -> (['subjective'], array([0.28101832], dtype=float32))
# deductible -> (['insurance'], array([0.40744564], dtype=float32))
# sexual_misconduct -> (['allegations'], array([0.34078243], dtype=float32))
# child_molester -> (['pedo'], array([0.31891984], dtype=float32))
# wikipedia_page -> (['wikipedia'], array([0.27818373], dtype=float32))
# katie_johnson -> (['defendant'], array([0.33464912], dtype=float32))
# famously -> (['ultra'], array([0.29753467], dtype=float32))
# technicality -> (['boi'], array([0.25382906], dtype=float32))
# locker_room -> (['sexual_assault'], array([0.3159438], dtype=float32))
# gore -> (['mccain'], array([0.3838637], dtype=float32))
# delaying -> (['delay'], array([0.28108892], dtype=float32))
# grossly -> (['whore'], array([0.2535591], dtype=float32))
# robust -> (['ubi'], array([0.27494437], dtype=float32))
# influences -> (['convenient'], array([0.27009037], dtype=float32))
# comprehensive -> (['proposed'], array([0.29867473], dtype=float32))
# rivals -> (['hands'], array([0.27198592], dtype=float32))
# takeaway -> (['clarification'], array([0.31189543], dtype=float32))
# charismatic -> (['attractive'], array([0.30574542], dtype=float32))
# disproportionate -> (['population'], array([0.30357966], dtype=float32))
# committees -> (['committee'], array([0.40660307], dtype=float32))
# formally -> (['33'], array([0.29591036], dtype=float32))
# stagnant -> (['growth'], array([0.30950397], dtype=float32))
# dunleavy -> (['illinois'], array([0.27876654], dtype=float32))
# reich -> (['indentured_servants'], array([0.26646864], dtype=float32))
# winger -> (['wing'], array([0.29604033], dtype=float32))
# semblance -> (['backbone'], array([0.2849957], dtype=float32))
# moral_compass -> (['depth'], array([0.28715926], dtype=float32))
# rambling -> (['rant'], array([0.31430668], dtype=float32))
# illustrate -> (['precisely'], array([0.2792647], dtype=float32))
# proposing -> (['solutions'], array([0.30411083], dtype=float32))
# propagandist -> (['ben_shapiro'], array([0.31260914], dtype=float32))
# bonds -> (['currency'], array([0.38074198], dtype=float32))
# pensions -> (['debt'], array([0.31485647], dtype=float32))
# transactions -> (['stock_market'], array([0.31065664], dtype=float32))
# mattis -> (['sessions'], array([0.35838604], dtype=float32))
# hyperbolic -> (['racist'], array([0.27003604], dtype=float32))
# indicative -> (['represents'], array([0.2886858], dtype=float32))
# broader -> (['nuance'], array([0.28215775], dtype=float32))
# military_industrial -> (['globalist'], array([0.32663226], dtype=float32))
# press_secretary -> (['buzzfeed'], array([0.34862489], dtype=float32))
# cope -> (['degeneracy'], array([0.26467723], dtype=float32))
# nationally -> (['polling'], array([0.27811474], dtype=float32))
# sexual_predator -> (['rapist'], array([0.4079842], dtype=float32))
# incremental -> (['moderates'], array([0.27602112], dtype=float32))
# palatable -> (['moderate'], array([0.28125262], dtype=float32))
# generalize -> (['intolerant'], array([0.3518534], dtype=float32))
# unsubstantiated -> (['false'], array([0.31148568], dtype=float32))
# warranted -> (['plausible'], array([0.26190615], dtype=float32))
# airtime -> (['tickets'], array([0.28958315], dtype=float32))
# alaskan -> (['joking'], array([0.28104338], dtype=float32))
# legislative_branch -> (['executive_branch'], array([0.34878513], dtype=float32))
# correcting -> (['recycling'], array([0.26881275], dtype=float32))
# abandoning -> (['tyranny'], array([0.25703356], dtype=float32))
# zero_tolerance -> (['daca'], array([0.3963316], dtype=float32))
# prioritize -> (['gaining'], array([0.26196647], dtype=float32))
# humane -> (['compassionate'], array([0.32656732], dtype=float32))
# 96 -> (['green_cards'], array([0.28869775], dtype=float32))
# cruelty -> (['hatred'], array([0.35380167], dtype=float32))
# presents -> (['starring'], array([0.24247551], dtype=float32))
# trades -> (['loan'], array([0.31273097], dtype=float32))
# dubious -> (['prepared'], array([0.27172413], dtype=float32))
# baffling -> (['horrifying'], array([0.287631], dtype=float32))
# passionate -> (['about'], array([0.27902067], dtype=float32))
# rightwingers -> (['leftists'], array([0.34834626], dtype=float32))
# bartenders -> (['blue_collar'], array([0.27575615], dtype=float32))
# reflects -> (['dedication'], array([0.30206826], dtype=float32))
# formula -> (['apportionment'], array([0.2844188], dtype=float32))
# semantics -> (['pointless'], array([0.31404972], dtype=float32))
# rednecks -> (['too'], array([0.28012553], dtype=float32))
# sociopath -> (['larp'], array([0.2866975], dtype=float32))
# parroting -> (['talking'], array([0.32313856], dtype=float32))
# heritage_foundation -> (['constitutional'], array([0.27914318], dtype=float32))
# misuse -> (['collect'], array([0.258105], dtype=float32))
# sanitation -> (['food'], array([0.34994423], dtype=float32))
# deadline -> (['court'], array([0.3210039], dtype=float32))
# donny -> (['aw'], array([0.34842917], dtype=float32))
# unpaid -> (['paid'], array([0.33791012], dtype=float32))
# affiliated -> (['supports'], array([0.275162], dtype=float32))
# superpower -> (['germany'], array([0.33085102], dtype=float32))
# lane -> (['bridge'], array([0.3140497], dtype=float32))
# launching -> (['battle'], array([0.26387444], dtype=float32))
# defeating -> (['andrew_jackson'], array([0.24585593], dtype=float32))
# obstructionist -> (['nefarious'], array([0.28343192], dtype=float32))
# dear_leader -> (['rain'], array([0.29342908], dtype=float32))
# waitress -> (['bartender'], array([0.38066], dtype=float32))
# antigun -> (['gun'], array([0.32369652], dtype=float32))
# large_portion -> (['droves'], array([0.2715234], dtype=float32))
# citation_needed -> (['nbsp'], array([0.2872299], dtype=float32))
# goddamned -> (['finished'], array([0.27335972], dtype=float32))
# redundant -> (['helpful'], array([0.2990061], dtype=float32))
# reeks -> (['accuse'], array([0.26140445], dtype=float32))
# mouthpiece -> (['oppress'], array([0.2853558], dtype=float32))
# spokesman -> (['recalled'], array([0.27616358], dtype=float32))
# narcissism -> (['insanity'], array([0.29053336], dtype=float32))
# progression -> (['decline'], array([0.28026775], dtype=float32))
# flaw -> (['mistake'], array([0.26380727], dtype=float32))
# parallels -> (['south_africa'], array([0.28599325], dtype=float32))
# divisions -> (['divide'], array([0.33555138], dtype=float32))
# screws -> (['tube'], array([0.30908394], dtype=float32))
# mobilize -> (['fight'], array([0.27351505], dtype=float32))
# scales -> (['reach'], array([0.29939148], dtype=float32))
# distrust -> (['hate'], array([0.28468522], dtype=float32))
# gleefully -> (['turn'], array([0.24245647], dtype=float32))
# blue_wave -> (['2020'], array([0.3507378], dtype=float32))
# insecurity -> (['projection'], array([0.28626856], dtype=float32))
# 1968 -> (['90s'], array([0.31590208], dtype=float32))
# persuade -> (['convince'], array([0.2899985], dtype=float32))
# objection -> (['ssn'], array([0.23757258], dtype=float32))
# counterparts -> (['than'], array([0.25165337], dtype=float32))
# evangelicals -> (['christians'], array([0.36162412], dtype=float32))
# mitch_mcconnell -> (['senate'], array([0.35531506], dtype=float32))
# overturned -> (['scotus'], array([0.29991433], dtype=float32))
# capital_gains -> (['tax'], array([0.40344748], dtype=float32))
# perspectives -> (['topics'], array([0.28357932], dtype=float32))
# pleas -> (['defendant'], array([0.3003114], dtype=float32))
# pardons -> (['mueller'], array([0.3329487], dtype=float32))
# approved_source -> (['`'], array([0.47034848], dtype=float32))
# whitelist -> (['submission'], array([0.42952752], dtype=float32))
# domains_must -> (['link_shortener'], array([0.38163188], dtype=float32))
# acceptable_source -> (['moderators'], array([0.36281082], dtype=float32))
# notable -> (['recent'], array([0.2760851], dtype=float32))
# domain_notability -> (['moderators'], array([0.42079297], dtype=float32))
# notable_domains -> (['moderators'], array([0.4331957], dtype=float32))
# research_organizations -> (['^shape_^or'], array([0.46991265], dtype=float32))
# political_advocacy -> (['^in_^any'], array([0.4394315], dtype=float32))
# governmental_agencies -> (['^incite_^violence'], array([0.45038614], dtype=float32))
# /_bodies -> (['^in_^any'], array([0.4655456], dtype=float32))
# contain_articles -> (['^incite_^violence'], array([0.40922445], dtype=float32))
# soundclips_relevant -> (['link_shortener'], array([0.3985622], dtype=float32))
# politics_contain -> (['link_shortener'], array([0.35813394], dtype=float32))
# original_content -> (['link_shortener'], array([0.38656935], dtype=float32))
# rehosted -> (['accessible'], array([0.3347076], dtype=float32))
# approved_whitelist -> (['performed_automatically'], array([0.46761918], dtype=float32))
# submit_spam -> (['please_contact'], array([0.42851105], dtype=float32))
# breaking_content -> (['please_contact'], array([0.43274572], dtype=float32))
# spam_domain -> (['performed_automatically'], array([0.5434005], dtype=float32))
# site_administrators -> (['link_shortener'], array([0.48107997], dtype=float32))
# instructions_provided -> (['performed_automatically'], array([0.71877486], dtype=float32))
# rammed -> (['ports'], array([0.38869867], dtype=float32))
# oligarchy -> (['cultural_marxism'], array([0.30587426], dtype=float32))
# trumpism -> (['authoritarianism'], array([0.30802223], dtype=float32))
# gwb -> (['clinton'], array([0.2802725], dtype=float32))
# demented -> (['misogynist'], array([0.30674908], dtype=float32))
# dehumanizing -> (['concentration_camp'], array([0.3049951], dtype=float32))
# undoubtedly -> (['stat'], array([0.2577429], dtype=float32))
# qualities -> (['dominant'], array([0.30469933], dtype=float32))
# seizing -> (['ownership'], array([0.26704982], dtype=float32))
# toothpaste -> (['soap'], array([0.4358076], dtype=float32))
# minimize -> (['monetary'], array([0.2611383], dtype=float32))
# border_crossings -> (['border'], array([0.38178882], dtype=float32))
# forgiven -> (['student_loans'], array([0.32798284], dtype=float32))
# hesitant -> (['skeptical'], array([0.29179335], dtype=float32))
# slim -> (['bricks_handed'], array([0.28477225], dtype=float32))
# moot -> (['question'], array([0.2899771], dtype=float32))
# al_gore -> (['bush'], array([0.29784915], dtype=float32))
# socialized -> (['hiring'], array([0.29600438], dtype=float32))
# anecdote -> (['upload'], array([0.30422872], dtype=float32))
# statewide -> (['electoral_college'], array([0.31609666], dtype=float32))
# neglected -> (['heartbreaking'], array([0.28510144], dtype=float32))
# shortsighted -> (['baiting'], array([0.2912421], dtype=float32))
# upwards -> (['40'], array([0.2799716], dtype=float32))
# peddling -> (['b.s'], array([0.27190667], dtype=float32))
# filtered -> (['link_shortener'], array([0.34656197], dtype=float32))
# rehosted_content -> (['link_shortener'], array([0.40499568], dtype=float32))
# intellectually -> (['pathetic'], array([0.2831642], dtype=float32))
# insufficient -> (['oxygen'], array([0.29380524], dtype=float32))
# construct -> (['request'], array([0.26560104], dtype=float32))
# 12k -> (['$'], array([0.37170395], dtype=float32))
# diverted -> (['emergency'], array([0.32123554], dtype=float32))
# income_inequality -> (['growth'], array([0.33429942], dtype=float32))
# nevertheless -> (['defeat'], array([0.26052126], dtype=float32))
# progun -> (['libertarian'], array([0.31229764], dtype=float32))
# insurers -> (['health'], array([0.33456227], dtype=float32))
# treatments -> (['medical'], array([0.3341345], dtype=float32))
# interned -> (['qualifies'], array([0.3022413], dtype=float32))
# embarrass -> (['ashamed'], array([0.28238732], dtype=float32))
# outlandish -> (['credible'], array([0.2979736], dtype=float32))
# rethink -> (['heck'], array([0.25361207], dtype=float32))
# indicator -> (['skeptical'], array([0.29641652], dtype=float32))
# weakest -> (['best'], array([0.2881251], dtype=float32))
# daily_caller -> (['news'], array([0.35166094], dtype=float32))
# paradox -> (['tolerance'], array([0.30724624], dtype=float32))
# trillion_dollars -> (['dollars'], array([0.3815536], dtype=float32))
# locally -> (['local'], array([0.3151274], dtype=float32))
# perceive -> (['mobs'], array([0.2818609], dtype=float32))
# uniquely -> (['sight'], array([0.27282572], dtype=float32))
# assault_weapons -> (['gun'], array([0.3615611], dtype=float32))
# best_tl -> (['performed_automatically'], array([0.4121861], dtype=float32))
# original_reduced -> (['dr'], array([0.34822068], dtype=float32))
# ideally -> (['ensure'], array([0.25452614], dtype=float32))
# extended_summary -> (['|'], array([0.37845287], dtype=float32))
# |_faq -> (['|'], array([0.39523032], dtype=float32))
# |_feedback -> (['|'], array([0.40611884], dtype=float32))
# top_keywords -> (['|'], array([0.477068], dtype=float32))
# validity -> (['findings'], array([0.27791196], dtype=float32))
# navigate -> (['os'], array([0.2930058], dtype=float32))
# analyze -> (['regulate'], array([0.29278573], dtype=float32))
# theoretical -> (['require'], array([0.2827223], dtype=float32))
# boston_university -> (['economics'], array([0.36455247], dtype=float32))
# #_039 -> (['gt'], array([0.38012096], dtype=float32))
# sidelines -> (['sit'], array([0.27826613], dtype=float32))
# quarters -> (['week'], array([0.26605088], dtype=float32))
# trump^_# -> (['myvote'], array([0.43418947], dtype=float32))
# garland -> (['judges'], array([0.33240622], dtype=float32))
# assertion -> (['fact'], array([0.283778], dtype=float32))
# physically_harmed -> (['performed_automatically'], array([0.30661252], dtype=float32))
# mistakenly -> (['consumption'], array([0.2706846], dtype=float32))
# unemployment_rate -> (['unemployment'], array([0.37058455], dtype=float32))
# absolve -> (['blame'], array([0.31889516], dtype=float32))
# wealth_inequality -> (['cultural_marxism'], array([0.3328577], dtype=float32))
# hicks -> (['white'], array([0.27149853], dtype=float32))
# corporatist -> (['rino'], array([0.3285195], dtype=float32))
# toddlers -> (['children'], array([0.37804723], dtype=float32))
# ramp -> (['hol'], array([0.29947218], dtype=float32))
# sickness -> (['hospital'], array([0.28068557], dtype=float32))
# productivity -> (['wages'], array([0.38026857], dtype=float32))
# equating -> (['conflate'], array([0.2545449], dtype=float32))
# false_equivalence -> (['al_qaeda'], array([0.28111535], dtype=float32))
# electable -> (['moderates'], array([0.3199093], dtype=float32))
# voter_turnout -> (['vote'], array([0.43295538], dtype=float32))
# pursuing -> (['degree'], array([0.2636081], dtype=float32))
# overcrowded -> (['facilities'], array([0.3809336], dtype=float32))
# apologists -> (['posters'], array([0.30050945], dtype=float32))
# fossil_fuel -> (['climate_change'], array([0.30985737], dtype=float32))
# focuses -> (['warfare'], array([0.27574423], dtype=float32))
# treasury -> (['tax_returns'], array([0.30188426], dtype=float32))
# 1980s -> (['90s'], array([0.34556368], dtype=float32))
# corroborated -> (['ig'], array([0.32193866], dtype=float32))
# leagues -> (['world_cup'], array([0.38282937], dtype=float32))
# administrations -> (['blatant'], array([0.2856164], dtype=float32))
# bubbles -> (['voices'], array([0.29837462], dtype=float32))
# uprising -> (['attack'], array([0.2878531], dtype=float32))
# wasteful -> (['spending'], array([0.29109532], dtype=float32))
# premiums -> (['insurance'], array([0.3997472], dtype=float32))
# funnel -> (['money'], array([0.2955585], dtype=float32))
# imperialism -> (['jihad'], array([0.30846426], dtype=float32))
# whim -> (['bully'], array([0.25784135], dtype=float32))
# overcrowding -> (['toilets'], array([0.36432812], dtype=float32))
# shelters -> (['detention_centers'], array([0.34054056], dtype=float32))
# rifles -> (['guns'], array([0.42789415], dtype=float32))
# constitutes -> (['definition'], array([0.26079035], dtype=float32))
# enacted -> (['proposal'], array([0.29733938], dtype=float32))
# background_checks -> (['gun'], array([0.35762078], dtype=float32))
# purge -> (['infiltrate'], array([0.28096184], dtype=float32))
# drug_dealers -> (['stores'], array([0.31990114], dtype=float32))
# homicide -> (['offenses'], array([0.3371817], dtype=float32))
# extermination_camps -> (['nazis'], array([0.44452453], dtype=float32))
# standpoint -> (['blind'], array([0.2702275], dtype=float32))
# arise -> (['protections'], array([0.25988784], dtype=float32))
# washington_examiner -> (['nyt'], array([0.34326988], dtype=float32))
# respondents -> (['%'], array([0.2976539], dtype=float32))
# pedantic -> (['frankly'], array([0.28896546], dtype=float32))
# marcus -> (['home_depot'], array([0.31117955], dtype=float32))
# prefers -> (['obsessed'], array([0.29490966], dtype=float32))
# shitheads -> (['scum'], array([0.29454198], dtype=float32))
# hostility -> (['sexism'], array([0.3227541], dtype=float32))
# dismissive -> (['score'], array([0.2568308], dtype=float32))
# frightened -> (['millennial'], array([0.28157696], dtype=float32))
# ...
# preexisting_conditions -> (['health_insurance'], array([0.39031443], dtype=float32))
# federalist -> (['wikipedia'], array([0.32516667], dtype=float32))
# vetting -> (['visa'], array([0.32043043], dtype=float32))
# fellas -> (['antitrump_domain'], array([0.33719632], dtype=float32))
# polarized -> (['underrated_comment'], array([0.27601445], dtype=float32))
# i.e. -> (['nonetheless'], array([0.27142423], dtype=float32))
# cpb -> (['ice'], array([0.34698722], dtype=float32))
# quitting -> (['cubans'], array([0.25153255], dtype=float32))
# americorps -> (['graduated'], array([0.33906302], dtype=float32))
# blames -> (['blamed'], array([0.33060366], dtype=float32))
# apathy -> (['voting'], array([0.29264075], dtype=float32))
# coconspirators -> (['epstein'], array([0.3621197], dtype=float32))
# cherry_picked -> (['context'], array([0.31835085], dtype=float32))
# roy_moore -> (['nomination'], array([0.29446658], dtype=float32))
# proportional -> (['based'], array([0.27859092], dtype=float32))
# triumph -> (['spectacle'], array([0.29799238], dtype=float32))
# pharmaceutical -> (['companies'], array([0.30084735], dtype=float32))
# transit -> (['schools'], array([0.2910488], dtype=float32))
# 2021 -> (['2024'], array([0.33094013], dtype=float32))
# exaggeration -> (['delusional'], array([0.26726237], dtype=float32))
# discretion -> (['doj'], array([0.28409758], dtype=float32))
# caucuses -> (['election'], array([0.3944205], dtype=float32))
# adjusted -> (['applied'], array([0.27242857], dtype=float32))
# toured -> (['visited'], array([0.32173413], dtype=float32))
# clinging -> (['nonexistent'], array([0.2557088], dtype=float32))
# await -> (['processed'], array([0.32554775], dtype=float32))
# 538 -> (['polling'], array([0.3794914], dtype=float32))
# compromises -> (['tests'], array([0.26901263], dtype=float32))
# clarifying -> (['worded'], array([0.3312556], dtype=float32))
# ensures -> (['maintain'], array([0.2944266], dtype=float32))
# reforming -> (['reform'], array([0.31923], dtype=float32))
# conducting -> (['security'], array([0.29018962], dtype=float32))
# golfing -> (['obama'], array([0.29404488], dtype=float32))
# rejection -> (['death'], array([0.25597298], dtype=float32))
# antisemites -> (['pronoun'], array([0.27673474], dtype=float32))
# blank_check -> (['camp'], array([0.32419032], dtype=float32))
# pathological_liar -> (['big_transgression'], array([0.3057078], dtype=float32))
# socioeconomic -> (['ethnic'], array([0.2828063], dtype=float32))
# lengthy -> (['hearing'], array([0.2670822], dtype=float32))
# reunite -> (['detain'], array([0.34961286], dtype=float32))
# stooge -> (['puppet'], array([0.30719587], dtype=float32))
# struggled -> (['struggles'], array([0.26950994], dtype=float32))
# infection -> (['wound'], array([0.2991871], dtype=float32))
# distribute -> (['send'], array([0.2707549], dtype=float32))
# national_parks -> (['parks'], array([0.33634582], dtype=float32))
# fixes -> (['solve'], array([0.2798146], dtype=float32))
# illegally_crossing -> (['border'], array([0.44875744], dtype=float32))
# neoliberalism -> (['marxism'], array([0.3454412], dtype=float32))
# testified -> (['fbi'], array([0.29818076], dtype=float32))
# 1k -> (['$'], array([0.32997063], dtype=float32))
# clinics -> (['hospitals'], array([0.4144283], dtype=float32))
# refrain -> (['keep'], array([0.27073961], dtype=float32))
# approval_ratings -> (['approval_rating'], array([0.388407], dtype=float32))
# kompromat -> (['blackmail_material'], array([0.3144467], dtype=float32))
# shrinking -> (['rising'], array([0.31008592], dtype=float32))
# constructive -> (['classroom'], array([0.2422918], dtype=float32))
# vip_section -> (['celebration'], array([0.32633078], dtype=float32))
# leftleaning -> (['lefty'], array([0.3650713], dtype=float32))
# straightforward -> (['realistic'], array([0.28357217], dtype=float32))
# 120 -> (['$'], array([0.34412584], dtype=float32))
# court_dates -> (['illegal_aliens'], array([0.37331402], dtype=float32))
# subpoenas -> (['judges'], array([0.3382914], dtype=float32))
# personally_witnessed -> (['islam_violates'], array([0.3021345], dtype=float32))
# brazen -> (['muslim_1:33'], array([0.24391152], dtype=float32))
# commute -> (['area'], array([0.3266013], dtype=float32))
# migrant_detention -> (['facilities'], array([0.3303997], dtype=float32))
# oust -> (['farage'], array([0.27782744], dtype=float32))
# laundering -> (['money_laundering'], array([0.29492357], dtype=float32))
# wedge -> (['divide'], array([0.28771698], dtype=float32))
# transferred -> (['2017'], array([0.31629813], dtype=float32))
# resignation -> (['chief'], array([0.27301547], dtype=float32))
# derived -> (['granted'], array([0.23678675], dtype=float32))
# disprove -> (['ios'], array([0.27761084], dtype=float32))
# casinos -> (['real_estate'], array([0.29012853], dtype=float32))
# contributes -> (['unchecked'], array([0.25572714], dtype=float32))
# caged -> (['cages'], array([0.34813055], dtype=float32))
# disenfranchise -> (['legal'], array([0.3108373], dtype=float32))
# rains -> (['rain'], array([0.37131232], dtype=float32))
# pleaded -> (['anderson'], array([0.27527532], dtype=float32))
# ✓ -> (['🇺🇸🇺🇸🇺🇸'], array([0.29350838], dtype=float32))
# frivolous -> (['reactionary'], array([0.2658284], dtype=float32))
# civics -> (['education'], array([0.33182892], dtype=float32))
# congressional_districts -> (['electoral_votes'], array([0.4504072], dtype=float32))
# contradiction -> (['hypocrisy'], array([0.29248765], dtype=float32))
# courses -> (['medical'], array([0.30507928], dtype=float32))
# appropriately -> (['prohibited'], array([0.2600606], dtype=float32))
# schemes -> (['guessing'], array([0.29098356], dtype=float32))
# nps -> (['parks'], array([0.28096917], dtype=float32))
# 1812 -> (['revolutionary_war'], array([0.4092742], dtype=float32))
# hague -> (['jail'], array([0.33911714], dtype=float32))
# supplemental_insurance -> (['medicare'], array([0.39650398], dtype=float32))
# susan_collins -> (['donates'], array([0.26696935], dtype=float32))
# rallying -> (['protest'], array([0.28484315], dtype=float32))
# fortunes -> (['corporations'], array([0.2904087], dtype=float32))
# drowned -> (['loud'], array([0.29326034], dtype=float32))
# 64 -> (['43'], array([0.29960638], dtype=float32))
# tougher -> (['voter_id'], array([0.25567645], dtype=float32))
# extremes -> (['centrists'], array([0.30998436], dtype=float32))
# e.g. -> (['including'], array([0.25765592], dtype=float32))
# collar -> (['crime'], array([0.3195479], dtype=float32))
# july_12th -> (['spirit_cooking'], array([0.29951292], dtype=float32))
# border_crossers -> (['border'], array([0.36261922], dtype=float32))
# resorts -> (['maralago'], array([0.35288733], dtype=float32))
# cultists -> (['lurkers'], array([0.2868439], dtype=float32))
# exoneration -> (['barr'], array([0.30557156], dtype=float32))
# mustard -> (['hot_dogs'], array([0.34599298], dtype=float32))
# annually -> (['million'], array([0.3439886], dtype=float32))
# litigation -> (['fec'], array([0.3447027], dtype=float32))
# dictates -> (['sovereignty'], array([0.26754525], dtype=float32))
# centre -> (['radical'], array([0.30109444], dtype=float32))
# harming -> (['align'], array([0.25551343], dtype=float32))
# certified -> (['dmv'], array([0.29212108], dtype=float32))
# reacting -> (['acting'], array([0.28209412], dtype=float32))
# steadily -> (['since'], array([0.27593994], dtype=float32))
# calculation -> (['assessment'], array([0.25698632], dtype=float32))
# climbing -> (['running'], array([0.2840599], dtype=float32))
# lite -> (['moderate'], array([0.29053152], dtype=float32))
# active_measures -> (['matrix'], array([0.28803316], dtype=float32))
# redistricting -> (['census'], array([0.3820647], dtype=float32))
# halt -> (['eliminate'], array([0.23116359], dtype=float32))
# comcast -> (['facebook'], array([0.27920544], dtype=float32))
# distinguished -> (['bricks_handed'], array([0.27084246], dtype=float32))
# military_personnel -> (['military'], array([0.29875302], dtype=float32))
# disclosure -> (['documents'], array([0.29534808], dtype=float32))
# storms -> (['rain'], array([0.33667564], dtype=float32))
# parole -> (['grand_jury'], array([0.3019912], dtype=float32))
# caging -> (['children'], array([0.27828935], dtype=float32))
# lucrative -> (['professional'], array([0.33259577], dtype=float32))
# counterproductive -> (['tos'], array([0.26372927], dtype=float32))
# alternatively -> (['compelling'], array([0.25373283], dtype=float32))
# retraining -> (['promised'], array([0.33962372], dtype=float32))
# abu_ghraib -> (['sexual_abuse'], array([0.29886723], dtype=float32))
# rushing -> (['august'], array([0.26791066], dtype=float32))
# jill_stein -> (['2016'], array([0.34181428], dtype=float32))
# distinction_between -> (['distinction'], array([0.32550958], dtype=float32))
# spade -> (['neocon'], array([0.29522076], dtype=float32))
# susceptible -> (['multiply'], array([0.26610485], dtype=float32))
# customs_enforcement -> (['dhs'], array([0.36509198], dtype=float32))
# state_legislatures -> (['elections'], array([0.36835632], dtype=float32))
# sexual_encounter -> (['defendant'], array([0.34495527], dtype=float32))
# fiscal_responsibility -> (['uphold'], array([0.2946841], dtype=float32))
# demagogue -> (['incredibly'], array([0.26855484], dtype=float32))
# panama_papers -> (['wikileaks'], array([0.36276066], dtype=float32))
# 140 -> (['inflation'], array([0.27343157], dtype=float32))
# tshirts -> (['hat'], array([0.34574836], dtype=float32))
# bonuses -> (['revenue'], array([0.38498062], dtype=float32))
# ticking -> (['maximum'], array([0.26125523], dtype=float32))
# dictionary_definition -> (['definition'], array([0.32623836], dtype=float32))
# vacant -> (['seat'], array([0.2671666], dtype=float32))
# complacency -> (['tick_tock'], array([0.3139479], dtype=float32))
# plaintiff -> (['defendant'], array([0.43915808], dtype=float32))
# neal -> (['tax_returns'], array([0.31931603], dtype=float32))
# disservice -> (['dedication'], array([0.2604384], dtype=float32))
# chomsky -> (['marxism'], array([0.31776643], dtype=float32))
# hamberders -> (['pasta'], array([0.35683313], dtype=float32))
# cbp_officers -> (['cbp'], array([0.33372208], dtype=float32))
# collins -> (['she'], array([0.30217424], dtype=float32))
# 67 -> (['30'], array([0.33537954], dtype=float32))
# sherman -> (['army'], array([0.30112067], dtype=float32))
# hypothesis -> (['science'], array([0.32654318], dtype=float32))
# franken -> (['karem'], array([0.39397344], dtype=float32))
# boycotted -> (['boycott'], array([0.41120955], dtype=float32))
# strongly_worded -> (['ag_barr'], array([0.29663327], dtype=float32))
# districting -> (['representation'], array([0.38481894], dtype=float32))
# exam -> (['helmet'], array([0.29073295], dtype=float32))
# blimp -> (['balloon'], array([0.4385019], dtype=float32))
# renewable_energy -> (['coal'], array([0.31989652], dtype=float32))
# ethically -> (['accurately'], array([0.25581786], dtype=float32))
# tourism -> (['alaska'], array([0.27996206], dtype=float32))
# ww1 -> (['wwii'], array([0.39254642], dtype=float32))
# abolish_ice -> (['border_patrol'], array([0.2937104], dtype=float32))
# lumber -> (['lowes'], array([0.4654129], dtype=float32))
# polygraphs -> (['informant'], array([0.27781674], dtype=float32))
# uscis -> (['border_patrol'], array([0.31214663], dtype=float32))
# polygraph -> (['compromised'], array([0.29151016], dtype=float32))
# child_pornography -> (['arrested'], array([0.3557985], dtype=float32))
# kasich -> (['ryan'], array([0.2892295], dtype=float32))
# justin_amash -> (['crenshaw'], array([0.29503816], dtype=float32))
# broadly -> (['prejudice'], array([0.25715557], dtype=float32))
# steyer -> (['nuts'], array([0.2617531], dtype=float32))
# disenfranchisement -> (['3/5ths'], array([0.31612888], dtype=float32))
# death_spiral -> (['stunt'], array([0.26871026], dtype=float32))
# tying -> (['bringing'], array([0.29543677], dtype=float32))
# 1.3_million -> (['million'], array([0.31134966], dtype=float32))
# bill_weld -> (['nominee'], array([0.37979856], dtype=float32))
# pfd -> (['millionaires'], array([0.2710481], dtype=float32))
# victories -> (['loss'], array([0.3128082], dtype=float32))
# ky -> (['district'], array([0.30624992], dtype=float32))
# anchorage -> (['los_angeles'], array([0.31902522], dtype=float32))
# kaiser -> (['medical'], array([0.31525025], dtype=float32))
# enabler -> (['rapist'], array([0.3373458], dtype=float32))
# executive_privilege -> (['sdny'], array([0.3274131], dtype=float32))
# vip -> (['lincoln_memorial'], array([0.38181022], dtype=float32))
# paragraphs -> (['references'], array([0.3145778], dtype=float32))
# defeatist -> (['reddit_admins'], array([0.2997442], dtype=float32))
# faucet -> (['toilets'], array([0.39232552], dtype=float32))
# separately -> (['hoped'], array([0.2614228], dtype=float32))
# ramparts -> (['ports'], array([0.40371123], dtype=float32))
# red_glare -> (['ports'], array([0.34244248], dtype=float32))
# massive_amounts -> (['massive'], array([0.29331407], dtype=float32))
# private_jet -> (['lolita_express'], array([0.45471814], dtype=float32))
# equal_protection -> (['clause'], array([0.32764262], dtype=float32))
# sherman_tanks -> (['airports'], array([0.322322], dtype=float32))
# edwards -> (['flight_logs'], array([0.3777144], dtype=float32))
# ramming -> (['militia'], array([0.27069962], dtype=float32))
# wv -> (['rural'], array([0.3738352], dtype=float32))
# draft_dodging -> (['motherfucker'], array([0.28495267], dtype=float32))
# 20190702 -> (["get'em"], array([0.2765], dtype=float32))
# kentuckians -> (['republicans'], array([0.29656327], dtype=float32))
# criminal_activity -> (['perjury'], array([0.267887], dtype=float32))
# drug_trafficking -> (['punishable'], array([0.30630362], dtype=float32))
# alaskans -> (['teachers'], array([0.26431775], dtype=float32))
# surkov_theater -> (['maryland'], array([0.30100918], dtype=float32))
# surkov -> (['saturday'], array([0.30439228], dtype=float32))
# known_jeff -> (['jeffrey_epstein'], array([0.3450626], dtype=float32))
# jeffrey_enjoys -> (['jeffrey_epstein'], array([0.3235325], dtype=float32))
# tpp -> (['negotiating'], array([0.30512175], dtype=float32))
# star_spangled -> (['ports'], array([0.33029777], dtype=float32))
# dentist -> (['doctors'], array([0.32186767], dtype=float32))
# alex_acosta -> (['acosta'], array([0.43700418], dtype=float32))
# labor_secretary -> (['acosta'], array([0.47339314], dtype=float32))
# respective_numbers -> (['shall'], array([0.3638831], dtype=float32))
# excluding_indians -> (['persons'], array([0.48497242], dtype=float32))
# undercount -> (['census'], array([0.42553], dtype=float32))
# kraft -> (['epstein'], array([0.38483116], dtype=float32))
# memos -> (['leaked'], array([0.31114432], dtype=float32))
# 2019_✓ -> (['veterans'], array([0.31432325], dtype=float32))
# 2018_✓ -> (['45'], array([0.26661563], dtype=float32))
# washington_monument -> (['lincoln_memorial'], array([0.4329138], dtype=float32))
# drug_traffickers -> (['illegally'], array([0.32605857], dtype=float32))
# amy_mcgrath -> (['beto'], array([0.30317256], dtype=float32))
# alan_dershowitz -> (['epstein'], array([0.48009375], dtype=float32))
# kobach -> (['amash'], array([0.29437897], dtype=float32))
# recusal -> (['prosecutors'], array([0.40018293], dtype=float32))
# dental_insurance -> (['medicare'], array([0.39496005], dtype=float32))
# rained -> (['july_4th'], array([0.3490898], dtype=float32))
# gallagher -> (['informant'], array([0.299303], dtype=float32))
# 20190703 -> (['myvote'], array([0.29153243], dtype=float32))
# lou_dobbs -> (['fucking'], array([0.29041395], dtype=float32))
# honeybees -> (['co2'], array([0.3498724], dtype=float32))
# freedom_caucus -> (['uniparty'], array([0.27551192], dtype=float32))
# usmnt -> (['world_cup'], array([0.4725302], dtype=float32))
# jane_doe -> (['testimony'], array([0.37038997], dtype=float32))
# recuse_himself -> (['sdny'], array([0.37372684], dtype=float32))
# rampart -> (['samurai'], array([0.29921442], dtype=float32))
# teleprompters -> (['teleprompter'], array([0.32276624], dtype=float32))
# fort_mchenry -> (['ports'], array([0.31640717], dtype=float32))
# army_manned -> (['ports'], array([0.36439326], dtype=float32))
# mcgrath -> (['2024'], array([0.32097068], dtype=float32))
# menards -> (['lowe'], array([0.46415785], dtype=float32))
